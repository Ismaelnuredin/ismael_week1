# %%
# Exploratory Data Analysis (EDA)

#This notebook demonstrates how to perform EDA on the dataset `raw_analyst_ratings` without relying on external modules or folders. All required code is self-contained within this notebook.

# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
from wordcloud import WordCloud
from collections import Counter
import nltk

# Download necessary NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       1 # Exploratory Data Analysis (EDA)
#       2
#       3 #This notebook demonstrates how to perform EDA on the dataset `raw_analyst_ratings` without relying on external modules or folders. All required code is self-contained within this notebook.
#       4
#       5 # Import necessary libraries
# ----> 6 import pandas as pd
#       7 import matplotlib.pyplot as plt
#       8 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'
